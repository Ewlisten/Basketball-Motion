# %% [markdown]
# <a href="https://colab.research.google.com/github/Ewlisten/Basketball-Motion/blob/main/Basketball_Motion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# !pip install ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="2zWr1IWK0uNCszPDo3Ob")
project = rf.workspace("basketball-motion").project("basketball-motion-owdql")
version = project.version(1) #first pass It would be good to add more basketball images
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 86.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.9 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model.train(data='/content/Basketball-Motion,-1/data.yaml', epochs=30, imgsz=640
)
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO("runs/detect/train2/weights/best.pt")
results = model.predict(source="/content/FAST_BREAK.MOV", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/254) /content/FAST_BREAK.MOV: 320x640 1 ball, 7 players, 183.8ms
# video 1/1 (frame 2/254) /content/FAST_BREAK.MOV: 320x640 1 ball, 7 players, 174.0ms
# video 1/1 (frame 3/254) /content/FAST_BREAK.MOV: 320x640 1 ball, 7 players, 141.2ms
# video 1/1 (frame 4/254) /content/FAST_BREAK.MOV: 320x640 1 ball, 7 players, 139.4ms
# video 1/1 (frame 5/254) /content/FAST_BREAK.MOV: 320x640 1 ball, 6 players, 127.2ms
# ...
